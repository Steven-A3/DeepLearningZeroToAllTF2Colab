# %% [markdown]
# # Lab 05 Logistic Classification (diabetes) - Eager Execution
# * Logistic Classfication을 diabetes data를 활용하여 모델을 만들어 보도록 하겠습니다
# ### 기본 Library 선언 및 Tensorflow 버전 확인

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

tf.random.set_seed(333)
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # 강의에 설명할 Data입니다.

# %% [markdown]
# ## 구글 드라이브 마운트해서 파일 읽기
#
# ### 구글 드라이브 접근 권한 얻기
#
# 파일 경로 지정에 주의하세요. 처음 여기서 시간 많이 씁니다.
# * 대소문자 주의
# * 여백 문자 주의

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
xy = np.loadtxt('/content/gdrive/My Drive/Colab Notebooks/TensorFlow 2 (ME)/data-03-diabetes.csv', delimiter=',', dtype=np.float32)
x_train = xy[:, 0:-1]
y_train = xy[:, [-1]]

print(x_train.shape, y_train.shape)
print(xy)
# Out:
# (759, 8) (759, 1)
# [[-0.294118   0.487437   0.180328  ... -0.53117   -0.0333333  0.       ]
#  [-0.882353  -0.145729   0.0819672 ... -0.766866  -0.666667   1.       ]
#  [-0.0588235  0.839196   0.0491803 ... -0.492741  -0.633333   0.       ]
#  ...
#  [-0.411765   0.21608    0.180328  ... -0.857387  -0.7        1.       ]
#  [-0.882353   0.266332  -0.0163934 ... -0.768574  -0.133333   0.       ]
#  [-0.882353  -0.0653266  0.147541  ... -0.797609  -0.933333   1.       ]]

# %% [markdown]
# ##  Tensorflow 2
#
# ### 위 Data를 기준으로 가설의 검증을 통해 Logistic Classification 모델을 만들도록 하겠습니다.
# * Tensorflow data API를 통해 학습시킬 값들을 구성합니다. (Batch Size는 한번에 학습시킬 Size)

# %%
dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(len(x_train))

# %% [markdown]
# ### 위 Data를 기준으로 가설과 검증을 통해 Logistic Classification 모델을 만들도록 하겠습니다.
#
# * W 변수와 b 변수는 학습을 통해 계산될 모델에 쓰이는 Wegith와 Bias
# * 0 또는 Random 값으로 초기화 합니다. tf.random_normal([2, 1])

# %%
W = tf.Variable(tf.random.normal((8, 1)), name='weight')
b = tf.Variable(tf.random.normal((1,)), name='bias')

# %% [markdown]
# ### Sigmoid 함수를 가설로 선언합니다
# * Sigmoid는 아래 그래프와 같이 0과 1의 값만을 리턴합니다 tf.sigmoid(tf.matmul(X, W) + b)와 같습니다
#
# $$
# \begin{align}
# sigmoid(x) & = \frac{1}{1+e^{-x}}  \\\\\
# \end{align}
# $$
#
# ![sigmoid](https://upload.wikimedia.org/wikipedia/commons/8/88/Logistic-curve.svg)

# %%
def logistic_regression(features):
    hypothesis  = tf.divide(1., 1. + tf.exp(tf.matmul(features, W) + b))
    return hypothesis

# %% [markdown]
# ### 가설을 검증할 Cost 함수를 정의합니다
# $$
# \begin{align}
# cost(h(x),y) & = −log(h(x))  &  if  &  y=1 \\\\\
# cost(h(x),y) & = -log(1−h(x))  &  if  &  y=0
# \end{align}
# $$

# %% [markdown]
# * 위 두수식을 합치면 아래과 같습니다
# $$
# \begin{align}
# cost(h(x),y) & = −y log(h(x))−(1−y)log(1−h(x))
# \end{align}
# $$

# %%
def loss_fn(hypothesis, features, labels):
    cost = -tf.reduce_mean(labels * tf.math.log(logistic_regression(features)) + (1 - labels) * tf.math.log(1 - hypothesis))
    return cost

optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

# %% [markdown]
# ### 추론한 값은 0.5를 기준(Sigmoid 그래프 참조)로 0과 1의 값을 리턴합니다.
# * Sigmoid 함수를 통해 예측값이 0.5보다 크면 1을 반환하고 0.5보다 작으면 0으로 반환합니다.

# %%
def accuracy_fn(hypothesis, labels):
    predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
    accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, labels), dtype=tf.float32))
    return accuracy

# %% [markdown]
# ### GradientTape를 통해 경사값을 계산합니다.

# %%
def grad(hypothesis, features, labels):
    with tf.GradientTape() as tape:
        loss_value = loss_fn(logistic_regression(features),features,labels)
    return tape.gradient(loss_value, [W,b])

# %% [markdown]
# ### 학습을 실행합니다.

# %%
EPOCHS = 10001

for step in range(EPOCHS):
    for features, labels  in iter(dataset):
        grads = grad(logistic_regression(features), features, labels)
        optimizer.apply_gradients(grads_and_vars=zip(grads,[W,b]))
        if step % 1000 == 0:
            print("Iter: {}, Loss: {:.4f}".format(step, loss_fn(logistic_regression(features),features,labels)))
# Out:
# Iter: 0, Loss: 0.9626
# Iter: 1000, Loss: 0.7223
# Iter: 2000, Loss: 0.6363
# Iter: 3000, Loss: 0.5829
# Iter: 4000, Loss: 0.5497
# Iter: 5000, Loss: 0.5284
# Iter: 6000, Loss: 0.5144
# Iter: 7000, Loss: 0.5047

# %%
train_acc = accuracy_fn(logistic_regression(x_train), y_train)
print("Training Accuracy: {:.4f}".format(train_acc))
